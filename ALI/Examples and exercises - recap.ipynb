# %%
import sympy as sp
from scipy import *
from sympy import *
init_printing()
from IPython.display import display, Latex, HTML, Math
import numpy as np
import pandas as pd
from sympy import Rational as R

# %%
A=Matrix([[1,-3,2],[3,-8,8],[0,1,2],[1,0,8]])
b=Matrix([[1],[6],[3],[10]])



x = Matrix([[2],[1],[1]])
x2 = Matrix([10, 3, 0])

# A*x2 == b
A
# Out:
# ⎡1  -3  2⎤
# ⎢        ⎥
# ⎢3  -8  8⎥
# ⎢        ⎥
# ⎢0  1   2⎥
# ⎢        ⎥
# ⎣1  0   8⎦

# %%
# Exercise 3 (3.1.43)

A = randMatrix(5,5, seed=42)
B = randMatrix(5,5, seed=49)
A
A.det(), B.det(), (A+B).det(), A.det() + B.det()
# Out:
# (86424868, -1506548382, 3209672706, -1420123514)

# %% [markdown]
# #### Vector Space Examples

# %%
C = Matrix([[1, 0, -2, -2], [0,1,1,4],[3,-1,-7,3],[0, 0, 0, 0]])
C.rref()
C.nullspace()
# Out:
# ⎡⎡2 ⎤⎤
# ⎢⎢  ⎥⎥
# ⎢⎢-1⎥⎥
# ⎢⎢  ⎥⎥
# ⎢⎢1 ⎥⎥
# ⎢⎢  ⎥⎥
# ⎣⎣0 ⎦⎦
