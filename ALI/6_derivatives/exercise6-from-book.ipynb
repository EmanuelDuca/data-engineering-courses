# %%
import sympy as sp
from scipy import *
from sympy import *
init_printing()
from IPython.display import display, Latex, HTML, Math
import numpy as np
import pandas as pd
from sympy import Rational as R

# %%
# Exercise 6.5 (5.7.15-5.7.16)

A = Matrix([
    [-8, -12, -6 ], 
    [2,1 ,2],
    [7,12,5]
])

lambda_values =  A.eigenvals(multiple=True)
# lamba = -2, -1, 1 

aigenvects = A.eigenvects()
aigenvects

display(Latex(r"Eigenvalues: $"+ str(lambda_values) + r"$"))
display(aigenvects)

# Write your display here 
t = sp.symbols('t', real=True)
c1, c2, c3 = sp.symbols('c1 c2 c3')


display(Math(r'\vec{t} = c_1 \begin{pmatrix} 1 \\ 2 \\ 3 \end{pmatrix} + c_2 \begin{pmatrix} 0 \\ 1 \\ 2 \end{pmatrix} + c_3 \begin{pmatrix} -1 \\ 0 \\ 1 \end{pmatrix}'))
display(Math(r'\vec{t} = \begin{pmatrix} c_1 - c_3 \\ 2c_1 + c_2 \\ 3c_1 + 2c_2 + c_3 \end{pmatrix}'))

display(Math(r'x(t)= c_1 ' + latex(aigenvects[0][2][0]) + r' e^{' + latex(lambda_values[0]) + r't} + '
             r'c_2 ' + latex(aigenvects[1][2][0]) + r' e^{' + latex(lambda_values[1]) + r't} + '
             r'c_3 ' + latex(aigenvects[2][2][0]) + r' e^{' + latex(lambda_values[2]) + r't}'))
# Out:
# Eigenvalues: $[-2, -1, 1]$
# ⎡⎛       ⎡⎡-1⎤⎤⎞  ⎛       ⎡⎡-6/5⎤⎤⎞  ⎛      ⎡⎡-1 ⎤⎤⎞⎤
# ⎢⎜       ⎢⎢  ⎥⎥⎟  ⎜       ⎢⎢    ⎥⎥⎟  ⎜      ⎢⎢   ⎥⎥⎟⎥
# ⎢⎜-2, 1, ⎢⎢0 ⎥⎥⎟, ⎜-1, 1, ⎢⎢1/5 ⎥⎥⎟, ⎜1, 1, ⎢⎢1/4⎥⎥⎟⎥
# ⎢⎜       ⎢⎢  ⎥⎥⎟  ⎜       ⎢⎢    ⎥⎥⎟  ⎜      ⎢⎢   ⎥⎥⎟⎥
# ⎣⎝       ⎣⎣1 ⎦⎦⎠  ⎝       ⎣⎣ 1  ⎦⎦⎠  ⎝      ⎣⎣ 1 ⎦⎦⎠⎦
# $\displaystyle \vec{t} = c_1 \begin{pmatrix} 1 \\ 2 \\ 3 \end{pmatrix} + c_2 \begin{pmatrix} 0 \\ 1 \\ 2 \end{pmatrix} + c_3 \begin{pmatrix} -1 \\ 0 \\ 1 \end{pmatrix}$
# $\displaystyle \vec{t} = \begin{pmatrix} c_1 - c_3 \\ 2c_1 + c_2 \\ 3c_1 + 2c_2 + c_3 \end{pmatrix}$
# $\displaystyle x(t)= c_1 \left[\begin{matrix}-1\\0\\1\end{matrix}\right] e^{-2t} + c_2 \left[\begin{matrix}- \frac{6}{5}\\\frac{1}{5}\\1\end{matrix}\right] e^{-1t} + c_3 \left[\begin{matrix}-1\\\frac{1}{4}\\1\end{matrix}\right] e^{1t}$

# %%
U1 = Matrix([1, 1, 0])
U2 = Matrix([-1, 1, 0])
