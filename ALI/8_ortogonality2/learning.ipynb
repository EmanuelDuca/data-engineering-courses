# %%
import sympy as sp
from scipy import *
from sympy import *
init_printing()
from IPython.display import display, Latex, HTML, Math
import numpy as np
import pandas as pd
from sympy import Rational as R

# %%
u1 = Matrix([[1,2,1,1]]).T
u2 = Matrix([[-2,1,-1,1]]).T
u3 = Matrix([[1,1,-2,-1]]).T
u4 = Matrix([[-1,1,1,-1]]).T
v = Matrix([[4,2,-1,0]]).T
u1,u2,u3,u4

# Point a
# Show that u1,u2,u3,u4 is an orthogonal basis for R4
dot12 = u1.T * u2
dot13 = u1.T * u3
dot14 = u1.T * u4
dot23 = u2.T * u3
dot24 = u2.T * u4
dot34 = u3.T * u4
print("Dot Product",dot12[0],dot13[0],dot14[0],dot23[0],dot24[0],dot34[0])
print("The u4 is not orthogonal vector")

#Richard code
U = Matrix.hstack(u1,u2,u3,u4)
U.T * U, U.rref()
# Out:
# Dot Product 0 0 1 0 1 -1
# The u4 is not orthogonal vector
# ⎛⎡7  0  0   1 ⎤  ⎛⎡1  0  0  0⎤              ⎞⎞
# ⎜⎢            ⎥  ⎜⎢          ⎥              ⎟⎟
# ⎜⎢0  7  0   1 ⎥  ⎜⎢0  1  0  0⎥              ⎟⎟
# ⎜⎢            ⎥, ⎜⎢          ⎥, (0, 1, 2, 3)⎟⎟
# ⎜⎢0  0  7   -1⎥  ⎜⎢0  0  1  0⎥              ⎟⎟
# ⎜⎢            ⎥  ⎜⎢          ⎥              ⎟⎟
# ⎝⎣1  1  -1  4 ⎦  ⎝⎣0  0  0  1⎦              ⎠⎠

# %%
# independent, not orthogonal
u1,u2,u3,u4 = GramSchmidt((u1,u2,u3,u4))

# %%
#Pint B Write v as som of 2 vectors span{u1,u2} and other in span {u3,u4}
#Putem sa scriem v = v1"(proiectia lui v pe u1) + v2"(proiectia lui v pe u2)

z1 = v.project(u1) + v.project(u2)
z2 = v.project(u3) + v.project(u4)
z1,z2
# Out:
# ⎛⎡17/7⎤  ⎡11/7 ⎤⎞
# ⎜⎢    ⎥  ⎢     ⎥⎟
# ⎜⎢9/7 ⎥  ⎢ 5/7 ⎥⎟
# ⎜⎢    ⎥, ⎢     ⎥⎟
# ⎜⎢12/7⎥  ⎢-19/7⎥⎟
# ⎜⎢    ⎥  ⎢     ⎥⎟
# ⎝⎣2/7 ⎦  ⎣-2/7 ⎦⎠

# %%
# Gram-Schmidt process as in Example 2 to produce an orthogonal basis for the column space of
A = Matrix([
    [-10, 13,  7, -11],
    [  2,  1, -5,   3],
    [ -6,  3, 13,  -3],
    [ 16,-16, -2,   5],
    [  2,  1, -5,  -7]
])

# Get the columns as vectors
cols = [A.col(i) for i in range(A.shape[1])]

# Apply Gram-Schmidt to get an orthogonal basis
orthogonal_basis = GramSchmidt(cols)

display(orthogonal_basis)
# Out:
# ⎡⎡-10⎤  ⎡3 ⎤  ⎡6⎤  ⎡0 ⎤⎤
# ⎢⎢   ⎥  ⎢  ⎥  ⎢ ⎥  ⎢  ⎥⎥
# ⎢⎢ 2 ⎥  ⎢3 ⎥  ⎢0⎥  ⎢5 ⎥⎥
# ⎢⎢   ⎥  ⎢  ⎥  ⎢ ⎥  ⎢  ⎥⎥
# ⎢⎢-6 ⎥, ⎢-3⎥, ⎢6⎥, ⎢0 ⎥⎥
# ⎢⎢   ⎥  ⎢  ⎥  ⎢ ⎥  ⎢  ⎥⎥
# ⎢⎢16 ⎥  ⎢0 ⎥  ⎢6⎥  ⎢0 ⎥⎥
# ⎢⎢   ⎥  ⎢  ⎥  ⎢ ⎥  ⎢  ⎥⎥
# ⎣⎣ 2 ⎦  ⎣3 ⎦  ⎣0⎦  ⎣-5⎦⎦
