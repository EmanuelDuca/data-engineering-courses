# %%
import sympy as sp
from scipy import *
from sympy import *
init_printing()
from IPython.display import display, Latex, HTML, Math
import numpy as np
import pandas as pd
from sympy import Rational as R

# %% [markdown]
# ##### 7 - Orthogonality

# %%
# Exercise 1 (6.1.1)
u = Matrix([-1,2])
v = Matrix([4,6])
w = Matrix([3, -1,-5])
x = Matrix([6, -2, 3])

a = u.T*u
b = v.T*u
c = a[0] / b[0]

display(u.T*u)
display(v.T*u)

# u*u , v*u and (v*u)/(u*u)
# Out:
# [5]
# [8]

# %%
# Exercise 8
a = Matrix([
    [1/sqrt(10)],
    [3/sqrt(20)],
    [3/sqrt(20)]
])

b = Matrix([
    [3/sqrt(10)],
    [-1/sqrt(20)],
    [-1/sqrt(20)]
])

c = Matrix([
    [0],
    [-1/sqrt(2)],
    [1/sqrt(2)]
])
display(a.T * b)
display(a.norm())
# Out:
# [0]

# %%
#Ex from cource
'''
    GramSchmidt(x1,x2,x3))
    GramSchmidt(x1,x2,x3,x4),True) - IN orthogonal form
'''
# Out:
# '\n    GramSchmidt(x1,x2,x3))\n    GramSchmidt(x1,x2,x3,x4),True) - IN orthogonal form\n'

# %%
A = Matrix([[-6,-11,16],[2,5,-4],[-4,-5,10]])
A.eigenvects()
# Out:
# ⎡⎛      ⎡⎡2⎤⎤⎞  ⎛      ⎡⎡3 ⎤⎤⎞  ⎛      ⎡⎡7/3 ⎤⎤⎞⎤
# ⎢⎜      ⎢⎢ ⎥⎥⎟  ⎜      ⎢⎢  ⎥⎥⎟  ⎜      ⎢⎢    ⎥⎥⎟⎥
# ⎢⎜2, 1, ⎢⎢0⎥⎥⎟, ⎜3, 1, ⎢⎢-1⎥⎥⎟, ⎜4, 1, ⎢⎢-2/3⎥⎥⎟⎥
# ⎢⎜      ⎢⎢ ⎥⎥⎟  ⎜      ⎢⎢  ⎥⎥⎟  ⎜      ⎢⎢    ⎥⎥⎟⎥
# ⎣⎝      ⎣⎣1⎦⎦⎠  ⎝      ⎣⎣1 ⎦⎦⎠  ⎝      ⎣⎣ 1  ⎦⎦⎠⎦

# %%
c = log(E)
c
# Out:
# 1

# %%
u1 = Matrix([3, 1, 1])
u2 = Matrix([-1, 2, 1])
u3 = Matrix([-1, -4, 7])

U = Matrix.hstack(u1, u2, u3)
U.T*U
# Out:
# ⎡11  0  0 ⎤
# ⎢         ⎥
# ⎢0   6  0 ⎥
# ⎢         ⎥
# ⎣0   0  66⎦
